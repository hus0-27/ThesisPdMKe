       53.00756905, 55.63455281, 52.02288391, 50.09328707, 53.36758303,
       58.30213927, 59.33369391, 57.84246403, 57.99424356, 57.86775375,
       57.95089063, 54.77016454, 52.03321782, 54.07023568, 52.81117646,
       52.58692585, 55.83561879, 59.82056922, 60.47919015, 59.82246058,
       59.52672369, 60.7130051 , 61.89684723, 64.18893866, 57.72779856,
       61.68997176, 64.22084864, 66.86834415, 66.57549081, 64.35439256,
       63.32092353, 62.77224175, 61.27500079, 60.06358708, 62.12511241,
       62.79165939, 67.08740594, 71.03395615, 72.42262721, 71.76455622,
       71.02191937, 70.36341733, 70.40454957, 70.59273024, 69.77251548,
       68.58985166, 68.223011  , 68.22552307, 67.65926132, 67.24783662,
       68.09918736, 69.31836452, 69.572237  , 69.10988377, 68.7929802 ,
       68.65675749, 67.09891061, 68.12157501, 67.36642298, 66.89295758,
       66.84508645, 67.03478282, 67.47779897, 68.006375  , 66.84192279,
       68.18928084, 67.09078548, 67.8381146 , 66.84428885, 67.06825001,
       67.54320697, 68.64162854, 67.77546141, 68.87216541, 72.06309814,
       75.53029235, 75.2194093 , 72.75551274, 70.71254988, 69.54271688,
       68.99306167, 69.33342345, 71.79518774, 73.86273238, 71.26168922,
       67.76104267, 68.48502188, 72.42454719, 71.61671165, 69.20991236,
       67.94801507, 67.49146513, 67.62466351, 67.85358004, 67.01276009,
       66.05033465, 66.54722496, 67.52976552, 67.8607269 , 68.17891163,
       68.01789189, 67.53785242, 71.7701302 , 69.98181033, 69.77085326 ]

plt.step(np.linspace(0, 1, len(your_data)), your_data, color='black', linewidth=0.3, where='mid')

plt.title('')
plt.xlabel('Time')
plt.ylabel('Value')
plt.ylim(35, 80)

plt.grid(True)
plt.show()
len(your_data)
# Out:
# 1000

# %%
import csv
from datetime import datetime, timedelta

# Define start and end date/time
start_date = datetime(year=2008, month=11, day=11, hour=15, minute=0)
end_date = datetime(year=2008, month=12, day=11, hour=14, minute=45)

# Define number of data points
num_data_points = 700

# Calculate time delta between each data point
time_delta = (end_date - start_date) / (num_data_points - 1)

# Open the CSV file in append mode (a+)
with open("data.csv", "a+") as csvfile:
  # Create a CSV writer object
  writer = csv.writer(csvfile)

  # Check if the file is empty, write header if needed
  if csvfile.tell() == 0:
    writer.writerow(["Timestamp", "Data"])

  # Iterate through data points and write to CSV
  for i in range(num_data_points):
    timestamp = start_date + (time_delta * i)
    writer.writerow([timestamp.strftime("%Y-%m-%d %H:%M:%S"), your_data[i]])  # Replace 'your_data[i]' with your actual data

# %%
import csv
from datetime import datetime, timedelta

# Define start and end date/time
start_date = datetime(year=2008, month=11, day=11, hour=15, minute=0)
# end_date = datetime(year=2008, month=12, day=11, hour=14, minute=45)

# Define number of data points
num_data_points = 1000

# Calculate one-minute time delta
one_minute_delta = timedelta(minutes=15)

# Open the CSV file in append mode (a+)
with open("testSeasonal1denoised.csv", "a+") as csvfile:
  # Create a CSV writer object
  writer = csv.writer(csvfile)

  # Check if the file is empty, write header if needed
  if csvfile.tell() == 0:
    writer.writerow(["Timestamp", "Data"])

  # Iterate through data points and write to CSV
  for i in range(num_data_points):
    timestamp = start_date + (i * one_minute_delta)
    writer.writerow([timestamp.strftime("%Y-%m-%d %H:%M:%S"), your_data[i]])  # Replace 'your_data[i]' with your actual data
