# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from scipy import signal
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
df = pd.read_csv('airline-passengers.csv' ,parse_dates=True)
# df['Timestamp'] = pd.to_datetime(df['Timestamp'] ,  format = '%Y-%m-%d %H:%M:%S' )
# # df['Timestamp'] =  df['Timestamp'].dt.strftime('%Hh')
# df = df.set_index('Timestamp').resample('H').fillna(method='ffill')
# # df.index.freq='T'
df['Month'] = pd.to_datetime(df['Month'] ,  format = '%m' )
df['Month'] =  df['Month'].dt.strftime('%m')
df = df.set_index('Month')
# df.index.freq='M'
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv('airline-passengers.csv' ,parse_dates=True)
#       2 # df['Timestamp'] = pd.to_datetime(df['Timestamp'] ,  format = '%Y-%m-%d %H:%M:%S' )
#       3 # # df['Timestamp'] =  df['Timestamp'].dt.strftime('%Hh')
#       4 # df = df.set_index('Timestamp').resample('H').fillna(method='ffill')
#       5 # # df.index.freq='T'
#       6 df['Month'] = pd.to_datetime(df['Month'] ,  format = '%m' )
#
# NameError: name 'pd' is not defined

# %%
df['Passengers'].plot(color='black', linewidth=0.4, figsize=(8,6))

# plt.ylim(32, 70)

plt.xlim(0, len(df))
# plt.xticks(np.arange(0, len(df), step=len(df)/14))

plt.title('Point 1')

plt.xlabel('')
plt.ylabel('')

plt.grid(True)
# print(df['Data'])

# %%
df = pd.read_csv('airline-passengers.csv' ,  header=0, index_col=0)

results = seasonal_decompose(df['Passengers'], model='multiplicative')
results.plot();



# dff = df[(df['Data'])]
# detrended = signal.detrend(dff.num_sold.values)
# plt.plot(detrended)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 df = pd.read_csv('airline-passengers.csv' ,  header=0, index_col=0)
# ----> 3 results = seasonal_decompose(df['Passengers'], model='multiplicative')
#       4 results.plot()
#
# File ~\Desktop\Road 2 20\PreML\env\Lib\site-packages\statsmodels\tsa\seasonal.py:166, in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     164         period = pfreq
#     165     else:
# --> 166         raise ValueError(
#     167             "You must specify a period or x must be a pandas object with "
#     168             "a PeriodIndex or a DatetimeIndex with a freq not set to None"
#     169         )
#     170 if x.shape[0] < 2 * pfreq:
#     171     raise ValueError(
#     172         f"x must have 2 complete cycles requires {2 * pfreq} "
# ...

# %%
from pandas import read_csv
from matplotlib import pyplot
from statsmodels.tsa.seasonal import seasonal_decompose
import pandas as pd
series = read_csv('airline-passengers.csv')
# series = series.set_index('Month')
series.index.freq='MS'
print(series)

result = seasonal_decompose(series, model='additive')
result.plot()
# pyplot.show()
# Out:
#        Month  Passengers
# 0    1949-01         112
# 1    1949-02         118
# 2    1949-03         132
# 3    1949-04         129
# 4    1949-05         121
# ..       ...         ...
# 139  1960-08         606
# 140  1960-09         508
# 141  1960-10         461
# 142  1960-11         390
# 143  1960-12         432
#
# [144 rows x 2 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9128\3916804759.py in ?()
#       6 # series = series.set_index('Month')
#       7 series.index.freq='MS'
#       8 print(series)
#       9
# ---> 10 result = seasonal_decompose(series, model='additive')
#      11 result.plot()
#      12 # pyplot.show()
#
# ~\Desktop\Road 2 20\PreML\env\Lib\site-packages\statsmodels\tsa\seasonal.py in ?(x, model, filt, period, two_sided, extrapolate_trend)
#     145     pw = PandasWrapper(x)
# ...
